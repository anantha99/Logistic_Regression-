# %%
from sklearn import datasets
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

# %%
train_data = pd.read_csv(r'C:\Users\Ananthapadmanabha\Desktop\blogs\Untitled Folder\training_titanic_x_y_train.csv')
train_data['sex_factor'] = pd.factorize(train_data.Sex)[0]

# %%
columns_taken_for_training = ['SibSp','Pclass','sex_factor','Fare','Parch']
X = train_data[columns_taken_for_training]
Y = train_data.Survived

# %%
train_data
# Out:
#      Pclass                                            Name     Sex   Age  \
# 0         2   Weisz, Mrs. Leopold (Mathilde Francoise Pede)  female  29.0
# 1         3               Williams, Mr. Howard Hugh "Harry"    male   NaN
# 2         2  Morley, Mr. Henry Samuel ("Mr Henry Marshall")    male  39.0
# 3         3     Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0
# 4         3                          Sutehall, Mr. Henry Jr    male  25.0
# ..      ...                                             ...     ...   ...
# 663       2                             Ilett, Miss. Bertha  female  17.0
# 664       3                        Morrow, Mr. Thomas Rowan    male   NaN
# 665       3                                   Bing, Mr. Lee    male  32.0
# 666       3                     Strandberg, Miss. Ida Sofia  female  22.0
# 667       3                  Murphy, Miss. Katherine "Kate"  female   NaN
#
#      SibSp  Parch           Ticket     Fare Cabin Embarked  Survived  \
# ...

# %%
test_data = pd.read_csv(r'C:\Users\Ananthapadmanabha\Desktop\blogs\Untitled Folder\test_titanic_x_test.csv')
test_data['sex_factor'] = pd.factorize(test_data.Sex)[0]

columns_taken_for_training = ['SibSp','Pclass','sex_factor','Fare','Parch']
X_test = test_data[columns_taken_for_training]

# %%
test_data
# Out:
#      Pclass                                               Name     Sex   Age  \
# 0         2                     Davies, Master. John Morgan Jr    male   8.0
# 1         1                        Leader, Dr. Alice (Farnham)  female  49.0
# 2         3                            Kilgannon, Mr. Thomas J    male   NaN
# 3         2  Jacobsohn, Mrs. Sidney Samuel (Amy Frances Chr...  female  24.0
# 4         1                          McGough, Mr. James Robert    male  36.0
# ..      ...                                                ...     ...   ...
# 218       3                        Lindqvist, Mr. Eino William    male  20.0
# 219       1                  Butt, Major. Archibald Willingham    male  45.0
# 220       1  Penasco y Castellana, Mrs. Victor de Satode (M...  female  17.0
# 221       3                   Holm, Mr. John Fredrik Alexander    male  43.0
# 222       2           Navratil, Mr. Michel ("Louis M Hoffman")    male  36.5
#
# ...

# %%
cld = LogisticRegression(C=2,tol=0.001,penalty='l2',solver='sag')
cld.fit(X,Y)
Y_pred = cld.predict(X_test)
# Out:
# c:\Users\Ananthapadmanabha\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn("The max_iter was reached which means "

# %%
np.savetxt('logistic_regression_excel.csv',Y_pred, fmt='%1.0f')
